# %% [markdown]
# # [STARTER] Exercise - Building an Agentic RAG System
#
# In this exercise, you will build an Agentic RAG (Retrieval-Augmented Generation) system that
# combines the power of AI agents with traditional RAG pipelines. You'll create an agent that
# can decide when and how to retrieve information from different sources, including vector
# databases, web search, and other tools.

# %% [markdown]
# ## Challenge
#
# Your challenge is to create an Agentic RAG system that can:
#
# - Build a RAG pipeline as a tool that can be used by the agent
# - Create an agent that can decide which tool to use based on the query
# - Handle different types of queries intelligently
# - Combine information from multiple sources when needed

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
from typing import List
from dotenv import load_dotenv

from lib.agents import Agent
from lib.llm import LLM
from lib.state_machine import Run
from lib.messages import BaseMessage
from lib.tooling import tool
from lib.vector_db import VectorStoreManager, CorpusLoaderService
from lib.rag import RAG

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Load data to Vector DB

# %%
db = VectorStoreManager(OPENAI_API_KEY)
db
# Out:
# VectorStoreManager():<chromadb.api.client.Client object at 0x74ab600299a0>

# %%
loader_service = CorpusLoaderService(db)

# %%
rag_llm = LLM()

# %%
# TODO: Add the games pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method
pdf_path = "TheGamingIndustry2024.pdf"
games_market_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(store_name="gaming_industry", pdf_path=pdf_path)
)
# Out:
# VectorStore `gaming_industry` ready!
# Pages from `TheGamingIndustry2024.pdf` added!

# %%
result:Run = games_market_rag.invoke(
    "What's the  state of virtual reality"
)
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# The state of virtual reality (VR) in 2024 is characterized by significant advancements and growing integration into the gaming industry. VR technology allows gamers to immerse themselves in realistic and interactive digital environments, enhancing the gaming experience beyond traditional boundaries. Notable examples include games like "Half-Life: Alyx," which utilize high-fidelity graphics, intuitive controls, and immersive audio to create engaging experiences. Additionally, VR is being explored for educational purposes, providing immersive learning experiences and enhancing engagement in various fields. Overall, VR is a transformative technology that is reshaping how players interact with digital worlds and is expected to continue evolving in the coming years.

# %%
# TODO: Add the electric vehicles pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method
pdf_path = "GlobalEVOutlook2025.pdf"
electric_vehicles_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(store_name="electric_vehicles", pdf_path=pdf_path)
)
# Out:
# VectorStore `electric_vehicles` ready!
# Pages from `GlobalEVOutlook2025.pdf` added!

# %%
result:Run = electric_vehicles_rag.invoke("What was the number of electric car sales and their market share in Brazil in 2024?")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# In 2024, Brazil had nearly 125,000 electric car sales, which represented a market share of 6.5%.

# %% [markdown]
# ## Tools
#
# In a simple form, Agentic RAG can act like a router, choosing between multiple external sources to retrieve relevant information. These sources aren't limited to databases, they can also include tools like web search or APIs for services such as Slack or email.
#
# In this case it will choose between two collections.

# %%
# TODO: Define a tool that returns result.get_final_state()["answer"]
# DONOT Forget about defining the tool docstrings
@tool
def search_global_ev_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: Global EV Outlook 2025
    Publisher: International Energy Agency
    Release: May 2025
    ```
        The Global EV Outlook is an annual publication that reports on recent
        developments in electric mobility around the world. It is developed with the support
        of members of the Electric Vehicles Initiative (EVI).
    ```

    args:
        query (str): Search query
    """
    result:Run = electric_vehicles_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# TODO: Define a tool that returns result.get_final_state()["answer"]
# DONOT Forget about defining the tool docstrings
@tool
def search_games_market_report_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: The Gaming Industry in 2024 - Trends, Technologies & Predictions
    Publisher: Ixie Gaming
    Release: 2024
    ```
        The gaming industry, on the brink of transformative change due to technological
        advancements, is redefining entertainment and social interaction with
        immersive, personalized, and interactive experiences.
    ```

    args:
        query (str): Search query
    """
    result:Run = games_market_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# TODO: Add the tools you have defined and the instructions to your agent
agentic_rag = Agent(
    model_name="gpt-4o-mini",
    tools=[search_global_ev_collection, search_games_market_report_collection],
    instructions=(
        "You are an Agentic RAG assistant that can intelligently decide which tools to use "
        "to answer user questions. Reason about about the response, change the query and call the tool again if needed "
        "in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers."
    )
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages: 
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run

# %%
run_1 = agentic_rag.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
    session_id="oscar",
)

print("\nMessages from run 1:")
messages = run_1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Who won the 2025 Oscar for International Movie?, tool_calls = None)
#  -> (role = assistant, content = The 2025 Oscar winners are not available in my current dataset, as my training only includes information up until October 2023. Additionally, I don't have access to real-time data or updates beyond that point.
#
# To find out who won the 2025 Oscar for International Movie, I would recommend checking a reliable news source or the official Oscars website for the most accurate and up-to-date information., tool_calls = None)

# %%
run_2 = agentic_rag.invoke(
    query= (
        "Which two countries accounted for most of the electric car exports from " 
        "the Asia Pacific region (excluding China) in 2024?"
    ),
    session_id="electric_car",
)

print("\nMessages from run 2:")
messages = run_2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Which two countries accounted for most of the electric car exports from the Asia Pacific region (excluding China) in 2024?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_2wrqHR74pg9o3G0HQvRQeHjb', function=Function(arguments='{"query":"electric car exports Asia Pacific region 2024 excluding China"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, Japan and Korea accounted for the majority of the nearly 640,000 electric cars exported from the Asia Pacific region, excluding China, marking an increase of 15% from 2023. The United States was the main destination for these exports, making up more than a quarter of the total production from the region. Europe followed as the second-largest destination, importing another quarter of the region's electric car production.", tool_calls = None)
#  -> (role = assistant, content = In 2024, the two countries that accounted for most of the electric car exports from the Asia Pacific region, excluding China, were Japan and Korea. Together, they contributed significantly to the nearly 640,000 electric cars exported from the region, representing a 15% increase from the previous year., tool_calls = None)

# %%
run_3 = agentic_rag.invoke(
    query= (
        "Why is generative AI seen more as an accelerator than a replacement in game development?"
    ),
    session_id="games",
)

print("\nMessages from run 3:")
messages = run_3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Why is generative AI seen more as an accelerator than a replacement in game development?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_d7VVRyXR10L7SgAzGVpFr7Jb', function=Function(arguments='{"query":"generative AI accelerator in game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "Generative AI is playing a significant role as an accelerator in game development by enhancing the design, development, and overall gaming experience. It automates complex tasks, simulates intelligent behavior, and assists in creating dynamic non-player characters (NPCs) that respond to player actions in real-time. This technology not only improves realism in games but also adds depth to gameplay, making it a crucial innovation in the gaming industry.", tool_calls = None)
#  -> (role = assistant, content = Generative AI is viewed more as an accelerator than a replacement in game development for several reasons:
#
# 1. **Enhancement of Design and Development**: Generative AI automates complex tasks that traditionally require significant time and effort. This allows game developers to focus on higher-level creative processes while the AI handles tedious aspects of development.
#
# 2. **Simulation of Intelligent Behavior**: AI can create dynamic non-player characters (NPCs) that respond intelligently to player actions in real-time. This enhances the realism and immersion of the gaming experience, providing players with more engaging interactions.
#
# 3. **Improvement of Gameplay Depth**: By leveraging generative AI, developers can create richer game worlds with greater variability and player agency. This adds depth to gameplay, making the gaming experience more enjoyable and varied.
#
# 4. **Collaboration with Human Creativity**: Generative AI serves as a tool that complements human creativity rather than replacing it. Developers can use AI-generated content as a foundation or inspiration, allowing for a more collaborative and innovative development process.
#
# Overall, generative AI accelerates the game development process by improving efficiency, enhancing gameplay experiences, and supporting creative endeavors, rather than taking over the creative roles traditionally held by human developers., tool_calls = None)
